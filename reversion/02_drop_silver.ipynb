# %%
# %sql
DROP TABLE IF EXISTS adbsmartdatatdp.silver.sales;
DROP TABLE IF EXISTS adbsmartdatatdp.silver.customers;
DROP TABLE IF EXISTS adbsmartdatatdp.silver.products;
DROP TABLE IF EXISTS adbsmartdatatdp.silver.branches;
DROP TABLE IF EXISTS adbsmartdatatdp.silver.employees;
