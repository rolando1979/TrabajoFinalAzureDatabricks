# %%
# %sql
DROP TABLE IF EXISTS adbsmartdatatdp.gold.kpi_dashboard;
DROP TABLE IF EXISTS adbsmartdatatdp.gold.top_products;
DROP TABLE IF EXISTS adbsmartdatatdp.gold.top_customers;
DROP TABLE IF EXISTS adbsmartdatatdp.gold.sales_by_category;
DROP TABLE IF EXISTS adbsmartdatatdp.gold.sales_by_city;
DROP TABLE IF EXISTS adbsmartdatatdp.gold.sales_summary;
