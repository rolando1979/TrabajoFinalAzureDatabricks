# %%
# %sql
DROP TABLE IF EXISTS adbsmartdatatdp.bronze.sales_raw;
DROP TABLE IF EXISTS adbsmartdatatdp.bronze.customers_raw;
DROP TABLE IF EXISTS adbsmartdatatdp.bronze.products_raw;
DROP TABLE IF EXISTS adbsmartdatatdp.bronze.branches_raw;
DROP TABLE IF EXISTS adbsmartdatatdp.bronze.employees_raw;
