# %%
# %sql
USE CATALOG adbsmartdatatdp;

GRANT USE CATALOG
ON CATALOG adbsmartdatatdp
TO `account users`;

GRANT USE SCHEMA
ON SCHEMA adbsmartdatatdp.gold
TO `account users`;

GRANT SELECT
ON TABLE adbsmartdatatdp.gold.sales_summary
TO `account users`;

GRANT SELECT
ON TABLE adbsmartdatatdp.gold.kpi_dashboard
TO `account users`;
